# %%
pip install mysql-connector-python
# Out:
# ...
#   Obtaining dependency information for mysql-connector-python from https://files.pythonhosted.org/packages/d9/91/007a0d60fee8db4f7385075dc50bf62d2d359b417b374ec06b06ce6c2d64/mysql_connector_python-8.3.0-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB 326.8 kB/s eta 0:00:48
#    ---------------------------------------- 0.1/15.4 MB 581.0 kB/s eta 0:00:27
#    ---------------------------------------- 0.1/15.4 MB 708.1 kB/s eta 0:00:22
#    ---------------------------------------- 0.2/15.4 MB 706.2 kB/s eta 0:00:22
#     --------------------------------------- 0.2/15.4 MB 765.3 kB/s eta 0:00:20
#     --------------------------------------- 0.2/15.4 MB 758.5 kB/s eta 0:00:21
#     --------------------------------------- 0.3/15.4 MB 770.1 kB/s eta 0:00:20
# ...

# %%
import mysql.connector as conn

# %%
# establishing connection between jupyter to mysqlbench

mydb = conn.connect(host =  'localhost', user = 'root', passwd = 'Loveumom@123')

# %%
mydb # connection variable

# %%
cursor = mydb.cursor() 
# cursor is a pointer or a position from
# where system will start reading

"""
What is a Cursor?
A cursor is a control structure that enables traversal over the rows of a result set. 
It acts as a pointer that points to a specific row in a result set from a database query.

Why Do We Use Cursors?
Row-by-Row Processing: Cursors are used when you need to process each row individually. 
This is particularly useful when the application needs to perform operations on each row of a result set, 
such as updating data, performing calculations, or applying business logic.

Control Over Result Sets: Cursors provide more control over the navigation of result sets. 
You can move forward and backward through the rows, fetch specific rows, and loop through the data.

Fetching Large Result Sets: When dealing with large result sets, fetching all rows at once can be memory-intensive. 
Cursors allow fetching a few rows at a time, reducing memory usage.

How Cursors Work
Declare a Cursor: Define the cursor with the SQL query that determines the result set.

Open the Cursor: Execute the query and make the result set available for processing.

Fetch Rows: Retrieve individual rows from the result set. You can fetch one row at a time, multiple rows, or all rows depending on the application’s requirements.

Process Rows: Perform operations on the fetched rows.

Close the Cursor: Release the cursor when it's no longer needed to free up resources.

Optional: Deallocate the Cursor: In some database systems, explicitly deallocate the cursor to clean up resources.
"""

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sidfirst',),
#  ('sys',)]

# %%
# creating own database (table format)
# 1. establishing connection like here we did using connection variable mydb
# 2. cursior pointer

# %%
cursor = mydb.cursor()

# %%
# query to create new database

cursor.execute("create database sidfirst")

# %%
cursor.execute("create table sidfirst.sid1(studentid INT(10),firstname VARCHAR(30),lastname VARCHAR(30),regid INT(10),classname VARCHAR(30))")

# %%
# query to chaeck available tables in database
cursor.execute("use cursorsidfirst")
cursor.execute("show tables")
cursor.fetchall()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:661, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     660         query = query.encode("utf-8")
# --> 661     self._cmysql.query(
#     662         query,
#     663         raw=raw,
#     664         buffered=buffered,
#     665         raw_as_string=raw_as_string,
#     666         query_attrs=self.query_attrs,
#     667     )
#     668 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Unknown database 'cursorsidfirst'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[14], line 2
#       1 # query to chaeck available tables in database
# ----> 2 cursor.execute("use cursorsidfirst")
# ...

# %%
cursor.execute("insert into sidfirst.ineuron values(13234,'siddhant','patel',5485,'social')")

# %%
mydb.commit()

# %%
cursor.execute("select * from sidfirst.ineuron")

# %%
cursor.fetchall()
# Out:
# [(13234, 'siddhant', 'patel', 5485, 'social')]

# %%
# inserting a data in bulk in one shot
# 1. create table

# %%
cursor.execute('create table sidfirst.glassdata(c1 INT(10),c2 float(10,5),c3 float(10,5),c4 float(10,5),c5 float(10,5),c6 float(10,5),c7 float(10,5),c8 float(10,5),c9 float(10,5),c10 float(10,5),c11 INT(10))')

# %%
cursor.execute('show tables')
cursor.fetchall()
# Out:
# [('glassdata',), ('ineuron',)]

# %%
ls # to put file of data to this below folder where jupyter is pointing out
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is DC74-023C
#
#  Directory of C:\Users\admin\Desktop\PYTHON\SQL
#
# 02/06/2024  12:46 PM    <DIR>          .
# 02/06/2024  12:46 PM    <DIR>          ..
# 02/05/2024  10:17 AM    <DIR>          .ipynb_checkpoints
# 02/06/2024  12:46 PM            20,644 SQL-1.ipynb
#                1 File(s)         20,644 bytes
#                3 Dir(s)  119,785,394,176 bytes free

# %%
file = open("glass.data","r")

# %%
file.read()
# Out:
# '1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1\n2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1\n3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1\n4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1\n5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1\n6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1\n7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1\n8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1\n9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1\n10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1\n11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1\n12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1\n13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1\n14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1\n15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1\n16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1\n17,1.51784,12.68,3.67,1.16,73.11,0.61,8.70,0.00,0.00,1\n18,1.52196,14.36,3.85,0.89,71.36,0.15,9.15,0.00,0.00,1
# ...

# %%
import csv
with open ('glass.data','r') as f :
    glass_data = csv.reader(f,delimiter = '\n')
    for i in glass_data:
        print(i)  # print(i[0]) for removingn bracket nd ''
# Out:
# ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1']
# ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1']
# ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1']
# ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1']
# ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1']
# ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1']
# ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1']
# ['8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1']
# ['9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1']
# ['10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1']
# ['11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1']
# ['12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1']
# ['13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1']
# ['14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1']
# ['15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1']
# ['16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1']
# ...

# %%
cursor.execute('insert into sidfirst.glassdata values(1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1)')

# %%
mydb.commit()

# %%
cursor.execute('select * from sidfirst.glassdata')

# %%
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1)]

# %%
# now insert all of the data in one shot to mysql using python

# %%
with open ('glass.data','r') as f :
    glass_data = csv.reader(f,delimiter = '\n')
    for i in glass_data :
        print(i[0])
        cursor.execute(f'insert into sidfirst.glassdata values ({str(i[0])})')
mydb.commit()
# Out:
# 1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1
# 2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1
# 3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1
# 4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1
# 5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1
# 6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1
# 7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1
# 8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1
# 9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1
# 10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1
# 11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1
# 12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1
# 13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1
# 14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1
# 15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1
# 16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1
# 17,1.51784,12.68,3.67,1.16,73.11,0.61,8.70,0.00,0.00,1
# ...

# %%
import pandas as pd # using panda make it in tabular form

# %%
pd.read_sql('select * from sidfirst.glassdata',mydb)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_14564\977332751.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql('select * from sidfirst.glassdata',mydb)
#       c1       c2     c3    c4    c5     c6    c7    c8    c9  c10  c11
# 0      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0    1
# 1      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0    1
# 2      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0    1
# 3      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0    1
# 4      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0    1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...  ...  ...
# 425  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0    7
# 426  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0    7
# ...

# %%
pd.read_sql('show databases',mydb)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_14564\99043659.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql('show databases',mydb)
#              Database
# 0  information_schema
# 1               mysql
# 2  performance_schema
# 3            sidfirst
# 4                 sys
